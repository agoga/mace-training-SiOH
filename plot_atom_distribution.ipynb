# %% [markdown]
# # Visualize the Distribution of Number of Atoms in Training Data
# This notebook reads all structures from `mace_training_data.xyz`, counts the number of atoms in each, and plots a histogram of the distribution.

# %%
from ase.io import read
import matplotlib.pyplot as plt

# Read all structures from the training data
atoms_list = read("mace_training_data.xyz", ":")

# Get the number of atoms in each structure
num_atoms = [len(a) for a in atoms_list]

# Display a histogram of the distribution and save to file
plt.figure(figsize=(8, 5))
plt.hist(num_atoms, bins=20, edgecolor='black')
plt.xlabel('Number of atoms per structure')
plt.ylabel('Count')
plt.title('Distribution of number of atoms in training data')
plt.tight_layout()
plt.savefig("atom_count_hist.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from ase.io import read
#       2 import matplotlib.pyplot as plt
#       4 # Read all structures from the training data
#
# File ~/anaconda3/envs/lmp/lib/python3.11/site-packages/ase/io/__init__.py:6
#       4 from ase.io.formats import iread, read, string2index, write
#       5 from ase.io.netcdftrajectory import NetCDFTrajectory
# ----> 6 from ase.io.trajectory import PickleTrajectory, Trajectory
#       9 class ParseError(Exception):
#      10     """Parse error during reading of a file"""
#
# File ~/anaconda3/envs/lmp/lib/python3.11/site-packages/ase/io/trajectory.py:17
#      15 from ase.io.formats import is_compressed
#      16 from ase.io.jsonio import decode, encode
# ---> 17 from ase.io.pickletrajectory import PickleTrajectory
#      18 from ase.parallel import world
# ...

# %% [markdown]
# The histogram above is also saved as `atom_count_hist.png` in your working directory.
